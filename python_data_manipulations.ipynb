# %%
print("Hello")
# Out:
# Hello

# %%
def sum_all(n):
    return n*(n+1)/2

# %%
sum_all(2)
# Out:
# 3.0

# %%
sum_all(5)
# Out:
# 15.0

# %%
sum_all?
# Out:
# Signature: sum_all(n)
# Docstring: <no docstring>
# File:      /var/folders/q_/j8_hfn016sdflcrkyxj6l4d40000gn/T/ipykernel_70406/452617693.py
# Type:      function

# %%
customer_data=open("learning_data/retail_db/customers/part-00000",'r')

# %%
customer_data
# Out:
# <_io.TextIOWrapper name='learning_data/retail_db/customers/part-00000' mode='r' encoding='UTF-8'>

# %%
orders=open("learning_data/retail_db/orders/part-00000",'r')

# %%
orders_str=orders.read()

# %%
type(orders_str)
# Out:
# str

# %%
len(orders_str)
# Out:
# 2999944

# %%
orders_list=orders_str.splitlines()

# %%
orders_list
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '8,2013-07-25 00:00:00.0,2911,PROCESSING',
#  '9,2013-07-25 00:00:00.0,5657,PENDING_PAYMENT',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT',
#  '11,2013-07-25 00:00:00.0,918,PAYMENT_REVIEW',
#  '12,2013-07-25 00:00:00.0,1837,CLOSED',
#  '13,2013-07-25 00:00:00.0,9149,PENDING_PAYMENT',
#  '14,2013-07-25 00:00:00.0,9842,PROCESSING',
#  '15,2013-07-25 00:00:00.0,2568,COMPLETE',
#  '16,2013-07-25 00:00:00.0,7276,PENDING_PAYMENT',
#  '17,2013-07-25 00:00:00.0,2667,COMPLETE',
#  '18,2013-07-25 00:00:00.0,1205,CLOSED',
#  '19,2013-07-25 00:00:00.0,9488,PENDING_PAYMENT',
#  '20,2013-07-25 00:00:00.0,9198,PROCESSING',
#  '21,2013-07-25 00:00:00.0,2711,PENDING',
# ...

# %%
len(orders_list)
# Out:
# 68883

# %%
orders_list[:10]
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '8,2013-07-25 00:00:00.0,2911,PROCESSING',
#  '9,2013-07-25 00:00:00.0,5657,PENDING_PAYMENT',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT']

# %%
sec_order=orders_list[1]

# %%
sec_order
# Out:
# '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT'

# %%
sec_order.split(',')
# Out:
# ['2', '2013-07-25 00:00:00.0', '256', 'PENDING_PAYMENT']

# %%
l=[1,2,3,4]

# %%
l_all=[sum_all(n) for n in l]

# %%
sum_n=lambda n : n*(n+1)/2

# %%
map?
# Out:
# Init signature: map(function, iterable, /, *iterables)
# Docstring:
# Make an iterator that computes the function using arguments from
# each of the iterables.  Stops when the shortest iterable is exhausted.
# Type:           type
# Subclasses:

# %%
new_l_all=list(map(sum_n,l))
new_l_all
# Out:
# [1.0, 3.0, 6.0, 10.0]

# %%
new2_l_all=list(map(lambda n: n*(n+1)/2,l))
new2_l_all
# Out:
# [1.0, 3.0, 6.0, 10.0]

# %%
orders_list
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '8,2013-07-25 00:00:00.0,2911,PROCESSING',
#  '9,2013-07-25 00:00:00.0,5657,PENDING_PAYMENT',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT',
#  '11,2013-07-25 00:00:00.0,918,PAYMENT_REVIEW',
#  '12,2013-07-25 00:00:00.0,1837,CLOSED',
#  '13,2013-07-25 00:00:00.0,9149,PENDING_PAYMENT',
#  '14,2013-07-25 00:00:00.0,9842,PROCESSING',
#  '15,2013-07-25 00:00:00.0,2568,COMPLETE',
#  '16,2013-07-25 00:00:00.0,7276,PENDING_PAYMENT',
#  '17,2013-07-25 00:00:00.0,2667,COMPLETE',
#  '18,2013-07-25 00:00:00.0,1205,CLOSED',
#  '19,2013-07-25 00:00:00.0,9488,PENDING_PAYMENT',
#  '20,2013-07-25 00:00:00.0,9198,PROCESSING',
#  '21,2013-07-25 00:00:00.0,2711,PENDING',
# ...

# %%
completed_orders=list(filter(lambda orders_list: orders_list.split(',')[3] =='COMPLETE',orders_list)) # filter orders that are completed

# %%
completed_orders
# Out:
# ['3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '15,2013-07-25 00:00:00.0,2568,COMPLETE',
#  '17,2013-07-25 00:00:00.0,2667,COMPLETE',
#  '22,2013-07-25 00:00:00.0,333,COMPLETE',
#  '26,2013-07-25 00:00:00.0,7562,COMPLETE',
#  '28,2013-07-25 00:00:00.0,656,COMPLETE',
#  '32,2013-07-25 00:00:00.0,3960,COMPLETE',
#  '35,2013-07-25 00:00:00.0,4840,COMPLETE',
#  '45,2013-07-25 00:00:00.0,2636,COMPLETE',
#  '56,2013-07-25 00:00:00.0,10519,COMPLETE',
#  '63,2013-07-25 00:00:00.0,1148,COMPLETE',
#  '65,2013-07-25 00:00:00.0,5903,COMPLETE',
#  '67,2013-07-25 00:00:00.0,1406,COMPLETE',
#  '71,2013-07-25 00:00:00.0,8646,COMPLETE',
#  '72,2013-07-25 00:00:00.0,4349,COMPLETE',
#  '76,2013-07-25 00:00:00.0,6898,COMPLETE',
#  '80,2013-07-25 00:00:00.0,3007,COMPLETE',
#  '83,2013-07-25 00:00:00.0,1265,COMPLETE',
#  '88,2013-07-25 00:00:00.0,3809,COMPLETE',
# ...

# %%
completed_closed_orders=list(filter(lambda orders_list: orders_list.split(',')[3] in ('COMPLETE','CLOSED'),orders_list)) # filter orders that are completed and closed
completed_closed_orders
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '12,2013-07-25 00:00:00.0,1837,CLOSED',
#  '15,2013-07-25 00:00:00.0,2568,COMPLETE',
#  '17,2013-07-25 00:00:00.0,2667,COMPLETE',
#  '18,2013-07-25 00:00:00.0,1205,CLOSED',
#  '22,2013-07-25 00:00:00.0,333,COMPLETE',
#  '24,2013-07-25 00:00:00.0,11441,CLOSED',
#  '25,2013-07-25 00:00:00.0,9503,CLOSED',
#  '26,2013-07-25 00:00:00.0,7562,COMPLETE',
#  '28,2013-07-25 00:00:00.0,656,COMPLETE',
#  '32,2013-07-25 00:00:00.0,3960,COMPLETE',
#  '35,2013-07-25 00:00:00.0,4840,COMPLETE',
#  '37,2013-07-25 00:00:00.0,5863,CLOSED',
#  '45,2013-07-25 00:00:00.0,2636,COMPLETE',
#  '51,2013-07-25 00:00:00.0,12271,CLOSED',
#  '56,2013-07-25 00:00:00.0,10519,COMPLETE',
#  '57,2013-07-25 00:00:00.0,7073,CLOSED',
# ...

# %%
all_statuses=set(map(lambda orders: orders.split(',')[3],orders_list)) #unique statuses
all_statuses
# Out:
# {'CANCELED',
#  'CLOSED',
#  'COMPLETE',
#  'ON_HOLD',
#  'PAYMENT_REVIEW',
#  'PENDING',
#  'PENDING_PAYMENT',
#  'PROCESSING',
#  'SUSPECTED_FRAUD'}

# %%
orders_list[:5]
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE']

# %%
sorted?
# Out:
# Signature: sorted(iterable, /, *, key=None, reverse=False)
# Docstring:
# Return a new list containing all items from the iterable in ascending order.
#
# A custom key function can be supplied to customize the sort order, and the
# reverse flag can be set to request the result in descending order.
# Type:      builtin_function_or_method

# %%
sorted(orders_list)
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT',
#  '100,2013-07-25 00:00:00.0,12131,PROCESSING',
#  '1000,2013-07-30 00:00:00.0,2321,CLOSED',
#  '10000,2013-09-25 00:00:00.0,8983,PROCESSING',
#  '10001,2013-09-25 00:00:00.0,316,PENDING_PAYMENT',
#  '10002,2013-09-25 00:00:00.0,1530,COMPLETE',
#  '10003,2013-09-25 00:00:00.0,8099,COMPLETE',
#  '10004,2013-09-25 00:00:00.0,7768,CLOSED',
#  '10005,2013-09-25 00:00:00.0,541,COMPLETE',
#  '10006,2013-09-25 00:00:00.0,3974,COMPLETE',
#  '10007,2013-09-25 00:00:00.0,3375,PENDING',
#  '10008,2013-09-25 00:00:00.0,10516,PAYMENT_REVIEW',
#  '10009,2013-09-25 00:00:00.0,1942,ON_HOLD',
#  '1001,2013-07-30 00:00:00.0,6650,COMPLETE',
#  '10010,2013-09-25 00:00:00.0,3872,COMPLETE',
#  '10011,2013-09-25 00:00:00.0,3548,PENDING_PAYMENT',
#  '10012,2013-09-25 00:00:00.0,11849,PENDING_PAYMENT',
#  '10013,2013-09-25 00:00:00.0,5722,PROCESSING',
#  '10014,2013-09-25 00:00:00.0,10864,SUSPECTED_FRAUD',
# ...

# %%
sorted(orders_list,key=lambda orders: orders.split(',')[2]) # sorted on 3rd column ie Customer id
# Out:
# ['22945,2013-12-13 00:00:00.0,1,COMPLETE',
#  '45239,2014-05-01 00:00:00.0,10,COMPLETE',
#  '56133,2014-07-15 00:00:00.0,10,COMPLETE',
#  '6641,2013-09-05 00:00:00.0,100,COMPLETE',
#  '15045,2013-10-28 00:00:00.0,100,PROCESSING',
#  '22395,2013-12-09 00:00:00.0,100,CANCELED',
#  '28477,2014-01-16 00:00:00.0,100,COMPLETE',
#  '54995,2014-07-08 00:00:00.0,100,COMPLETE',
#  '62907,2014-02-06 00:00:00.0,100,PENDING_PAYMENT',
#  '64426,2014-04-06 00:00:00.0,100,PENDING',
#  '20020,2013-11-26 00:00:00.0,1000,COMPLETE',
#  '22368,2013-12-09 00:00:00.0,1000,PROCESSING',
#  '22513,2013-12-10 00:00:00.0,1000,PENDING',
#  '37498,2014-03-12 00:00:00.0,1000,COMPLETE',
#  '47858,2014-05-17 00:00:00.0,1000,COMPLETE',
#  '57680,2014-07-24 00:00:00.0,1000,CLOSED',
#  '62698,2014-01-29 00:00:00.0,1000,COMPLETE',
#  '5869,2013-08-30 00:00:00.0,10000,COMPLETE',
#  '24029,2013-12-21 00:00:00.0,10000,PENDING_PAYMENT',
#  '56521,2014-07-18 00:00:00.0,10000,COMPLETE',
# ...

# %%
sorted(orders_list,key=lambda orders: orders.split(',')[2],reverse=True) # sorted on 3rd column ie Customer id but in descending
# Out:
# ['3471,2013-08-14 00:00:00.0,9999,COMPLETE',
#  '41855,2014-04-09 00:00:00.0,9999,SUSPECTED_FRAUD',
#  '52395,2014-06-18 00:00:00.0,9999,CLOSED',
#  '55071,2014-07-08 00:00:00.0,9999,COMPLETE',
#  '62988,2014-02-09 00:00:00.0,9999,PENDING',
#  '11553,2013-10-04 00:00:00.0,9998,PENDING_PAYMENT',
#  '32253,2014-02-09 00:00:00.0,9998,PENDING_PAYMENT',
#  '41298,2014-04-04 00:00:00.0,9998,PROCESSING',
#  '59429,2013-09-29 00:00:00.0,9998,ON_HOLD',
#  '59713,2013-10-10 00:00:00.0,9998,CANCELED',
#  '39720,2014-03-27 00:00:00.0,9997,PENDING_PAYMENT',
#  '53678,2014-06-27 00:00:00.0,9997,COMPLETE',
#  '15839,2013-11-03 00:00:00.0,9996,PENDING',
#  '20782,2013-11-30 00:00:00.0,9996,ON_HOLD',
#  '26289,2014-01-03 00:00:00.0,9996,PENDING_PAYMENT',
#  '37694,2014-03-14 00:00:00.0,9996,CLOSED',
#  '45545,2014-05-03 00:00:00.0,9996,PROCESSING',
#  '48053,2014-05-18 00:00:00.0,9996,CLOSED',
#  '56036,2014-07-14 00:00:00.0,9996,ON_HOLD',
#  '57615,2014-07-24 00:00:00.0,9996,ON_HOLD',
# ...
